# %% [markdown]
# Import population data Khlong Toei District, Bangkok, Thailand

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#       District  Code      Thai Population   Latitude   Longitude
# 0  Huai Khwang    17  ห้วยขวาง     78,175  13.776667  100.579444
# 1       Lak Si    41   หลักสี่    109,770  13.887500  100.578889
# 2    Nong Chok     3   หนองจอก    157,138  13.855556  100.862500
# 3   Nong Khaem    23   หนองแขม    150,218  13.704722  100.348889
# 4      Sai Mai    42    สายไหม    188,123  13.919167  100.645833

# %%
from bs4 import BeautifulSoup
import requests # library to handle requests
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation



# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'AUREGHH5E55QA11PSLQRHVGGZGCFNC1DRJAYQZ4ABO201AQ0' # your Foursquare ID
CLIENT_SECRET = 'H3RD0BJXOIPOY2TNKBIDWYKI2HX31CNADWQDV14PA3K55A0Z' # your Foursquare Secret
CategoryID = '4d4b7105d754a06374d81259'
VERSION = '20180604'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: AUREGHH5E55QA11PSLQRHVGGZGCFNC1DRJAYQZ4ABO201AQ0
# CLIENT_SECRET:H3RD0BJXOIPOY2TNKBIDWYKI2HX31CNADWQDV14PA3K55A0Z

# %%
address = 'Khlong Toei, Bangkok, TH'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 13.7090525 100.5749075

# %%
search_query = 'Thailand'
radius = 30000
print(search_query + ' .... OK!')
# Out:
# Thailand .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?categoryId={}&client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CategoryID, CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4d4b7105d754a06374d81259&client_id=AUREGHH5E55QA11PSLQRHVGGZGCFNC1DRJAYQZ4ABO201AQ0&client_secret=H3RD0BJXOIPOY2TNKBIDWYKI2HX31CNADWQDV14PA3K55A0Z&ll=13.7090525,100.5749075&v=20180604&query=Thailand&radius=30000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e590efd0de0d9001ba381c0'},
#  'response': {'venues': [{'id': '4ce4d204d678a1cdfc2cac0c',
#     'name': 'Starbucks Coffee (Thailand) Co., Ltd.',
#     'location': {'address': '388 Sukhumvit Rd.',
#      'crossStreet': 'at Exchange Tower, 12th Fl.',
#      'lat': 13.735397095235477,
#      'lng': 100.56154025222274,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.735397095235477,
#        'lng': 100.56154025222274}],
#      'distance': 3269,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'neighborhood': 'Khlong Toei',
#      'city': 'คลองเตย',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['388 Sukhumvit Rd. (at Exchange Tower, 12th Fl.)',
#       'คลองเตย',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '59fdbcac1bc7043d43525a9c',
#     'name': 'Dogtails Thailand',
#     'location': {'lat': 13.7159605,
#      'lng': 100.57159,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.7159605,
#        'lng': 100.57159}],
#      'distance': 848,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['พระนคร', 'กรุงเทพมหานคร 10110', 'ประเทศไทย']},
#     'categories': [{'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'shortName': 'Pet Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5d174064d29cbb0023d86a9e',
#     'name': 'Lambretta Thailand Shop & Cafe',
#     'location': {'address': '589 Phra Sumen Rd.',
#      'lat': 13.757423,
#      'lng': 100.50449,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.757423,
#        'lng': 100.50449}],
#      'distance': 9326,
#      'postalCode': '10200',
#      'cc': 'TH',
#      'neighborhood': 'Bowon Niwet',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['589 Phra Sumen Rd.',
#       'พระนคร',
#       'กรุงเทพมหานคร 10200',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '57e9fc07498e7653e21e8a8f',
#     'name': 'CT Cafeteria by Club Thailand',
#     'location': {'lat': 13.733204237395244,
#      'lng': 100.5693505044712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.733204237395244,
#        'lng': 100.5693505044712}],
#      'distance': 2754,
#      'cc': 'TH',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['วัฒนา', 'กรุงเทพมหานคร', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5516aedf498ea477175fff0a',
#     'name': 'Kitaohji Thailand',
#     'location': {'address': '212 Thong Lo 8',
#      'crossStreet': 'Sukhumvit 55',
#      'lat': 13.730388,
#      'lng': 100.58233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.730388,
#        'lng': 100.58233}],
#      'distance': 2507,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'neighborhood': 'Vadhana',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['212 Thong Lo 8 (Sukhumvit 55)',
#       'วัฒนา',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4ff131ede4b0b29eb1d907c8',
#     'name': 'อิ่มอร่อย @ ibis Erawan Thailand',
#     'location': {'lat': 13.741183855932645,
#      'lng': 100.55112793750129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.741183855932645,
#        'lng': 100.55112793750129}],
#      'distance': 4405,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4ef7b905f9ab2e66823e164c',
#     'name': 'Thailand Tobacco Monopoly Flea Market',
#     'location': {'address': 'Thailand Tobacco Monopoly',
#      'lat': 13.723640138210492,
#      'lng': 100.55682739606067,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.723640138210492,
#        'lng': 100.55682739606067}],
#      'distance': 2541,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Thailand Tobacco Monopoly',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1f7941735',
#       'name': 'Flea Market',
#       'pluralName': 'Flea Markets',
#       'shortName': 'Flea Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4c7b941d2d3ba143164c94d0',
#     'name': 'Sing Thang Yeng Thailand (ซิงตังเอี๊ยง)',
#     'location': {'address': 'MBK Center',
#      'crossStreet': '4th Fl., Money Park',
#      'lat': 13.743931,
#      'lng': 100.53026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.743931,
#        'lng': 100.53026}],
#      'distance': 6195,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['MBK Center (4th Fl., Money Park)',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '53ef1403498e350b17a3a3ae',
#     'name': 'Nespresso By Coffee Concept Thailand',
#     'location': {'address': 'The Crystal Park',
#      'crossStreet': 'Phase 2 #KE107',
#      'lat': 13.811758736349738,
#      'lng': 100.61859131921517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.811758736349738,
#        'lng': 100.61859131921517}],
#      'distance': 12370,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['The Crystal Park (Phase 2 #KE107)',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '57d26d62498e018d16d2b84c',
#     'name': 'thailand',
#     'location': {'address': 'Bangkok , thailand',
#      'lat': 13.747911,
#      'lng': 100.490324,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.747911,
#        'lng': 100.490324}],
#      'distance': 10118,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Bangkok , thailand', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4e78278545ddedd585cbe99d',
#     'name': 'Thailand Dessert @Amarin Tower',
#     'location': {'lat': 13.744354234723778,
#      'lng': 100.5420241095705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.744354234723778,
#        'lng': 100.5420241095705}],
#      'distance': 5299,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['พระนคร', 'กรุงเทพมหานคร', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '56fcc4b2498e5f850f28159d',
#     'name': 'Thailand Boat Noodles',
#     'location': {'address': '61 Charoen Krung',
#      'lat': 13.714438,
#      'lng': 100.513426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.714438,
#        'lng': 100.513426}],
#      'distance': 6675,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['61 Charoen Krung',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '56aa371be4b08b9a8d57350b',
#       'name': 'Food Stand',
#       'pluralName': 'Food Stands',
#       'shortName': 'Food Stand',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4d9bc611f41ba14369bee8b3',
#     'name': 'Club Thailand Cafe',
#     'location': {'address': 'Sukhumvit 35 or 33/1',
#      'crossStreet': 'at sakura home 1st Fl.',
#      'lat': 13.733113964874727,
#      'lng': 100.56895812995312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.733113964874727,
#        'lng': 100.56895812995312}],
#      'distance': 2754,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Sukhumvit 35 or 33/1 (at sakura home 1st Fl.)',
#       'วัฒนา',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4bcec312c564ef3b4dbaeef0',
#     'name': 'Starbucks (สตาร์บัคส์)',
#     'location': {'address': '1 South Sathon Rd.',
#      'crossStreet': 'at Q.House Lumpini Life Center',
#      'lat': 13.725887441012231,
#      'lng': 100.54453467257596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.725887441012231,
#        'lng': 100.54453467257596}],
#      'distance': 3781,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'สาทร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['1 South Sathon Rd. (at Q.House Lumpini Life Center)',
#       'สาทร',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '50e6e7b3e4b0410885ab6cea',
#     'name': 'Thailand Street Food & Snack',
#     'location': {'address': 'Charoennakorn Road',
#      'lat': 13.71588978021978,
#      'lng': 100.51293472527472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.71588978021978,
#        'lng': 100.51293472527472}],
#      'distance': 6745,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Charoennakorn Road',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4b0587fbf964a520bfaa22e3',
#     'name': 'Thailand Tonight',
#     'location': {'address': '2 Charoen Krung Road Soi 30',
#      'lat': 13.728756539563452,
#      'lng': 100.514091926378,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.728756539563452,
#        'lng': 100.514091926378}],
#      'distance': 6932,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['2 Charoen Krung Road Soi 30',
#       'พระนคร',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '54b9f5d8498e7c86d1913fe0',
#     'name': 'Ippudo (อิปปุโดะ)',
#     'location': {'address': 'Emporium',
#      'crossStreet': '4th Fl, #4-8',
#      'lat': 13.730089487584287,
#      'lng': 100.56855815242757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.730089487584287,
#        'lng': 100.56855815242757}],
#      'distance': 2440,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'neighborhood': 'คลองเตย',
#      'city': 'คลองเตย',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Emporium (4th Fl, #4-8)',
#       'คลองเตย',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '55a59bace4b013909087cb24',
#       'name': 'Ramen Restaurant',
#       'pluralName': 'Ramen Restaurants',
#       'shortName': 'Ramen',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5c01028ddd12f8003947eb2c',
#     'name': 'Unatoto',
#     'location': {'address': '591/11-12 Soi Sukhumvit 33/1',
#      'lat': 13.732441131596467,
#      'lng': 100.56799627942986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.732441131596467,
#        'lng': 100.56799627942986}],
#      'distance': 2708,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'neighborhood': 'Vadhana',
#      'city': 'วัฒนา',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['591/11-12 Soi Sukhumvit 33/1',
#       'วัฒนา',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '545496ab498e75ddfe3bcda1',
#     'name': 'Thailand Northern Food',
#     'location': {'lat': 13.781572826929223,
#      'lng': 100.60888705684482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.781572826929223,
#        'lng': 100.60888705684482}],
#      'distance': 8869,
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['พระนคร', 'กรุงเทพมหานคร', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '50382342e4b05b4c7a7315aa',
#     'name': 'Breakfast room, novotel bangkok fenix ploenchit, thailand',
#     'location': {'lat': 13.742964046248304,
#      'lng': 100.54918842240599,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.742964046248304,
#        'lng': 100.54918842240599}],
#      'distance': 4688,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '50e6e93fe4b0e43377adb3d0',
#     'name': 'Thailand Street Food & Snack',
#     'location': {'address': 'Charoennakorn Road',
#      'lat': 13.760582815129283,
#      'lng': 100.50076877486885,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.760582815129283,
#        'lng': 100.50076877486885}],
#      'distance': 9857,
#      'cc': 'TH',
#      'neighborhood': 'Bowon Niwet',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Charoennakorn Road',
#       'พระนคร',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '53e0feef498e5aac066fd8a9',
#       'name': 'Street Food Gathering',
#       'pluralName': 'Street Food Gatherings',
#       'shortName': 'Street Food Gathering',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '588e3c21e18e653095f281ef',
#     'name': 'nice two Meat u',
#     'location': {'address': '266/9-10 Siam Square Soi 3',
#      'lat': 13.745266702627887,
#      'lng': 100.53294443253614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.745266702627887,
#        'lng': 100.53294443253614}],
#      'distance': 6069,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['266/9-10 Siam Square Soi 3',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5707ac73498ea5a842c3daa1',
#     'name': 'red sun thailand',
#     'location': {'address': 'Central Plaza RAMA IX',
#      'crossStreet': 'RAMA IX',
#      'lat': 13.758271,
#      'lng': 100.566111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.758271,
#        'lng': 100.566111}],
#      'distance': 5560,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Central Plaza RAMA IX (RAMA IX)', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '55732e3e498e61b3fa7c2f7c',
#     'name': "SIP 'N PLAY THAILAND",
#     'location': {'address': '12/500, 15 Sukhumvit Residences, Sukhumvit 15 , North Klongtoey, Wattana',
#      'lat': 13.741016098945066,
#      'lng': 100.55848360061646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.741016098945066,
#        'lng': 100.55848360061646}],
#      'distance': 3976,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['12/500, 15 Sukhumvit Residences, Sukhumvit 15 , North Klongtoey, Wattana',
#       'พระนคร',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '505c549fe4b0ef5c54dea309',
#     'name': 'Bagel & Bagel Thailand Office',
#     'location': {'lat': 13.741178,
#      'lng': 100.549662,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.741178,
#        'lng': 100.549662}],
#      'distance': 4499,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '55ceec64498e7647e66af6de',
#     'name': 'Snow Miku Café Mangania',
#     'location': {'address': 'Gateway Ekamai',
#      'lat': 13.718563205498887,
#      'lng': 100.58534814394471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.718563205498887,
#        'lng': 100.58534814394471}],
#      'distance': 1547,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'คลองเตย',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Gateway Ekamai',
#       'คลองเตย',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4b46a783f964a520512626e3',
#     'name': 'Starbucks (สตาร์บัคส์)',
#     'location': {'address': '39/1 Lang Suan Rd',
#      'lat': 13.741662159063543,
#      'lng': 100.5435419233945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.741662159063543,
#        'lng': 100.5435419233945}],
#      'distance': 4968,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['39/1 Lang Suan Rd',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5c2e0a8757a537002cdb33ae',
#     'name': 'Brunello Thailand',
#     'location': {'address': '15 Rama 9 Soi 58',
#      'lat': 13.740844139684416,
#      'lng': 100.62912225723267,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.740844139684416,
#        'lng': 100.62912225723267}],
#      'distance': 6848,
#      'postalCode': '10250',
#      'cc': 'TH',
#      'city': 'Suanluang',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['15 Rama 9 Soi 58',
#       'Suanluang',
#       'กรุงเทพมหานคร 10250',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '551953894'},
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4c075a14b4aa0f47d5876562',
#     'name': 'The Papaya (เดอะปาปาย่า)',
#     'location': {'address': '37 Soi Saladaeng 2',
#      'crossStreet': 'Thanon Sala Daeng',
#      'lat': 13.727648089872158,
#      'lng': 100.53531363170359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.727648089872158,
#        'lng': 100.53531363170359}],
#      'distance': 4755,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['37 Soi Saladaeng 2 (Thanon Sala Daeng)',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '59e34795121384138293ed1c',
#     'name': 'Uma Uma Thailand',
#     'location': {'crossStreet': 'Soi Narathiwas 1',
#      'lat': 13.728481,
#      'lng': 100.529832,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.728481,
#        'lng': 100.529832}],
#      'distance': 5332,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'Suriya Wong',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Soi Narathiwas 1',
#       'Suriya Wong',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '55a59bace4b013909087cb24',
#       'name': 'Ramen Restaurant',
#       'pluralName': 'Ramen Restaurants',
#       'shortName': 'Ramen',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '53ae73ce498eeba73dfb9be1',
#     'name': 'elosito thailand',
#     'location': {'lat': 13.74104,
#      'lng': 100.548548,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.74104,
#        'lng': 100.548548}],
#      'distance': 4561,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1db931735',
#       'name': 'Tapas Restaurant',
#       'pluralName': 'Tapas Restaurants',
#       'shortName': 'Tapas',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5632e3ed498eacee1a55d3ad',
#     'name': 'Macau Café Thailand',
#     'location': {'address': 'Macau Government Tourist Office',
#      'crossStreet': 'Ploenchit',
#      'lat': 13.742429,
#      'lng': 100.54905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.742429,
#        'lng': 100.54905}],
#      'distance': 4650,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Macau Government Tourist Office (Ploenchit)',
#       'พระนคร',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '579de061498e1748935e5e82',
#     'name': 'Snow Tree Thailand Korean Dessert Cafe at Sukhumvit11',
#     'location': {'address': '51 สุขุมวิทซอย11',
#      'crossStreet': 'สุขุมวิท',
#      'lat': 13.746908,
#      'lng': 100.55736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.746908,
#        'lng': 100.55736}],
#      'distance': 4621,
#      'postalCode': '10110',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['51 สุขุมวิทซอย11 (สุขุมวิท)',
#       'พระนคร',
#       'กรุงเทพมหานคร 10110',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4cf5d57fc020b60cbc0d1d75',
#     'name': 'Vegetarian Society of thailand',
#     'location': {'address': 'Kham pang phet',
#      'lat': 13.799308,
#      'lng': 100.54709,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.799308,
#        'lng': 100.54709}],
#      'distance': 10487,
#      'cc': 'TH',
#      'city': 'Jatujak',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Kham pang phet',
#       'Jatujak',
#       'กรุงเทพมหานคร',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4db62f970cb6729b6ab488c5',
#     'name': 'Foodcourt Tourist Authority of Thailand ศูนย์อาหาร กทท',
#     'location': {'lat': 13.749186,
#      'lng': 100.561286,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.749186,
#        'lng': 100.561286}],
#      'distance': 4704,
#      'cc': 'TH',
#      'city': 'มักกะสัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['มักกะสัน', 'กรุงเทพมหานคร', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4d269ca355a8b60ccf80bcc0',
#     'name': 'Pantry Room 43th Fl. Toyota Motors Thailand, All Season Place, Bangkok.',
#     'location': {'lat': 13.740937,
#      'lng': 100.547736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.740937,
#        'lng': 100.547736}],
#      'distance': 4607,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '52d782d1498ef8de63f1bd0b',
#     'name': 'Green Salad Thailand',
#     'location': {'address': '56,58 Soi Pipat (Soi Sathorn 8), Sathorn Nuea Road, Silom',
#      'crossStreet': 'Sathorn Soi 8',
#      'lat': 13.722605320077875,
#      'lng': 100.53155422210693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.722605320077875,
#        'lng': 100.53155422210693}],
#      'distance': 4925,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['56,58 Soi Pipat (Soi Sathorn 8), Sathorn Nuea Road, Silom (Sathorn Soi 8)',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1bd941735',
#       'name': 'Salad Place',
#       'pluralName': 'Salad Places',
#       'shortName': 'Salad',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4eb7bed1469073bbc71ba0c0',
#     'name': 'Coffee Sohety Thailand',
#     'location': {'lat': 13.727574348449707,
#      'lng': 100.53340911865234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.727574348449707,
#        'lng': 100.53340911865234}],
#      'distance': 4938,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4c1b4e84eac020a1829644c2',
#     'name': 'Chimney Coffee House',
#     'location': {'address': '734 Rama 3 Rd.',
#      'lat': 13.677538938515173,
#      'lng': 100.53000390529633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.677538938515173,
#        'lng': 100.53000390529633}],
#      'distance': 5991,
#      'postalCode': '10120',
#      'cc': 'TH',
#      'city': 'Yannawa',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['734 Rama 3 Rd.',
#       'Yannawa',
#       'กรุงเทพมหานคร 10120',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4b75306af964a52084002ee3',
#     'name': 'Sizzler (ซิซซ์เลอร์)',
#     'location': {'address': 'CentralWorld',
#      'crossStreet': '6th Fl, Beacon Zone',
#      'lat': 13.746652883110938,
#      'lng': 100.53994629334673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.746652883110938,
#        'lng': 100.53994629334673}],
#      'distance': 5640,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['CentralWorld (6th Fl, Beacon Zone)',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '569f7982498e6c13343a8194',
#     'name': 'Ippudo (Ippudo (一風堂))',
#     'location': {'address': 'Silom Complex',
#      'crossStreet': 'B Fl.',
#      'lat': 13.728415156601645,
#      'lng': 100.53510837762173,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.728415156601645,
#        'lng': 100.53510837762173}],
#      'distance': 4813,
#      'postalCode': '10500',
#      'cc': 'TH',
#      'city': 'บางรัก',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Silom Complex (B Fl.)',
#       'บางรัก',
#       'กรุงเทพมหานคร 10500',
#       'ประเทศไทย']},
#     'categories': [{'id': '55a59bace4b013909087cb24',
#       'name': 'Ramen Restaurant',
#       'pluralName': 'Ramen Restaurants',
#       'shortName': 'Ramen',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5bb715326336be002cf57e8d',
#     'name': 'Dookki Topokki',
#     'location': {'address': 'Esplanade Ratchadapisek',
#      'crossStreet': '2nd Fl',
#      'lat': 13.765702290116115,
#      'lng': 100.56959474313312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.765702290116115,
#        'lng': 100.56959474313312}],
#      'distance': 6332,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'Din Daeng',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Esplanade Ratchadapisek (2nd Fl)',
#       'Din Daeng',
#       'กรุงเทพมหานคร 10400',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5a1a635c8d0a532464fad961',
#     'name': 'Tsujiti Thailand',
#     'location': {'lat': 13.747235,
#      'lng': 100.534413,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.747235,
#        'lng': 100.534413}],
#      'distance': 6102,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'พระนคร',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['พระนคร', 'กรุงเทพมหานคร 10330', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '4f901a4ee4b076208a5eee89',
#     'name': 'Poly,s Hotel Thailand',
#     'location': {'lat': 13.749858170146716,
#      'lng': 100.54047484544577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.749858170146716,
#        'lng': 100.54047484544577}],
#      'distance': 5873,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '532bd2c9498eed57e0c62771',
#     'name': 'T bowl concept restaurant thailand',
#     'location': {'lat': 13.74574201866964,
#      'lng': 100.53009764734205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.74574201866964,
#        'lng': 100.53009764734205}],
#      'distance': 6337,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4edd64a0c7ddd24ca188df1a',
#       'name': 'Fish & Chips Shop',
#       'pluralName': 'Fish & Chips Shops',
#       'shortName': 'Fish & Chips',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fishandchips_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '55aa3aea498e7e5b3f176b0b',
#     'name': 'Big Time Lifestyle Cafe (Thailand)',
#     'location': {'lat': 13.759219,
#      'lng': 100.567875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.759219,
#        'lng': 100.567875}],
#      'distance': 5636,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5037a201e4b0e614ac2271ef',
#     'name': 'kaki lima thailand, Thailand',
#     'location': {'lat': 13.749197006225586,
#      'lng': 100.54056549072266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.749197006225586,
#        'lng': 100.54056549072266}],
#      'distance': 5810,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '5896c89032b0723568255130',
#     'name': 'Food Center Thailand',
#     'location': {'lat': 13.757669,
#      'lng': 100.554436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.757669,
#        'lng': 100.554436}],
#      'distance': 5847,
#      'postalCode': '10400',
#      'cc': 'TH',
#      'city': 'เขต ดินแดง',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['เขต ดินแดง', 'กรุงเทพมหานคร 10400', 'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '53c0c8b4498e3a62e88cf68b',
#     'name': 'Red Sun (เรดซัน)',
#     'location': {'address': 'Siam Square',
#      'crossStreet': 'near CU Book Center',
#      'lat': 13.74396972909405,
#      'lng': 100.53275970868997,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.74396972909405,
#        'lng': 100.53275970868997}],
#      'distance': 5990,
#      'postalCode': '10330',
#      'cc': 'TH',
#      'city': 'ปทุมวัน',
#      'state': 'กรุงเทพมหานคร',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['Siam Square (near CU Book Center)',
#       'ปทุมวัน',
#       'กรุงเทพมหานคร 10330',
#       'ประเทศไทย']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False},
#    {'id': '50398dc3e4b0451d7d22759a',
#     'name': 'breakfast room, Novotel Fenix Bangkok Ploenchit, Thailand',
#     'location': {'lat': 13.744347009717053,
#      'lng': 100.53472301899986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.744347009717053,
#        'lng': 100.53472301899986}],
#      'distance': 5858,
#      'cc': 'TH',
#      'country': 'ประเทศไทย',
#      'formattedAddress': ['ประเทศไทย']},
#     'categories': [{'id': '503288ae91d4c4b30a586d67',
#       'name': 'Afghan Restaurant',
#       'pluralName': 'Afghan Restaurants',
#       'shortName': 'Afghan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/afghan_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582894856',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 1  [{'id': '5032897c91d4c4b30a586d69', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...    False
# 4  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ce4d204d678a1cdfc2cac0c   388 Sukhumvit Rd.          TH       คลองเตย
# 1  59fdbcac1bc7043d43525a9c                 NaN          TH        พระนคร
# 2  5d174064d29cbb0023d86a9e  589 Phra Sumen Rd.          TH        พระนคร
# 3  57e9fc07498e7653e21e8a8f                 NaN          TH         วัฒนา
# 4  5516aedf498ea477175fff0a      212 Thong Lo 8          TH         วัฒนา
#
#   location.country         location.crossStreet  location.distance  \
# 0        ประเทศไทย  at Exchange Tower, 12th Fl.               3269
# 1        ประเทศไทย                          NaN                848
# 2        ประเทศไทย                          NaN               9326
# 3        ประเทศไทย                          NaN               2754
# 4        ประเทศไทย                 Sukhumvit 55               2507
#
#                            location.formattedAddress  \
# 0  [388 Sukhumvit Rd. (at Exchange Tower, 12th Fl...
# 1           [พระนคร, กรุงเทพมหานคร 10110, ประเทศไทย]
# 2  [589 Phra Sumen Rd., พระนคร, กรุงเทพมหานคร 102...
# 3                  [วัฒนา, กรุงเทพมหานคร, ประเทศไทย]
# 4  [212 Thong Lo 8 (Sukhumvit 55), วัฒนา, กรุงเทพ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 13.73539709523547...     13.735397
# 1  [{'label': 'display', 'lat': 13.7159605, 'lng'...     13.715960
# 2  [{'label': 'display', 'lat': 13.757423, 'lng':...     13.757423
# 3  [{'label': 'display', 'lat': 13.73320423739524...     13.733204
# 4  [{'label': 'display', 'lat': 13.730388, 'lng':...     13.730388
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    100.561540           Khlong Toei               10110  กรุงเทพมหานคร
# 1    100.571590                   NaN               10110  กรุงเทพมหานคร
# 2    100.504490           Bowon Niwet               10200  กรุงเทพมหานคร
# 3    100.569351                   NaN                 NaN  กรุงเทพมหานคร
# 28                Thai Restaurant
# 29               Ramen Restaurant
# 30               Tapas Restaurant
# 31                           Café
# 32                   Dessert Shop
# 33  Vegetarian / Vegan Restaurant
# 34                Thai Restaurant
# 35                    Coffee Shop
# 36                    Salad Place
# 37                           Café
# 38                    Coffee Shop
# 39                     Steakhouse
# 40               Ramen Restaurant
# 41              Korean Restaurant
# 42                 Ice Cream Shop
# 43                Thai Restaurant
# 44              Fish & Chips Shop
# 45                           Café
# 46               Asian Restaurant
# 47                     Food Court
# 48              Korean Restaurant
# 49              Afghan Restaurant
#
#                                               address  cc         city  \
# 0                                   388 Sukhumvit Rd.  TH      คลองเตย
# 1                                                 NaN  TH       พระนคร
# 2                                  589 Phra Sumen Rd.  TH       พระนคร
# 3                                                 NaN  TH        วัฒนา
# 4                                      212 Thong Lo 8  TH        วัฒนา
# 5                                                 NaN  TH          NaN
# 6                           Thailand Tobacco Monopoly  TH       พระนคร
# 7                                          MBK Center  TH      ปทุมวัน
# 8                                    The Crystal Park  TH       พระนคร
# 9                                  Bangkok , thailand  TH          NaN
# 10                                                NaN  TH       พระนคร
# 11                                   61 Charoen Krung  TH       พระนคร
# 12                               Sukhumvit 35 or 33/1  TH        วัฒนา
# 13                                 1 South Sathon Rd.  TH         สาทร
# 14                                 Charoennakorn Road  TH       พระนคร
# 15                        2 Charoen Krung Road Soi 30  TH       พระนคร
# 16                                           Emporium  TH      คลองเตย
# 17                       591/11-12 Soi Sukhumvit 33/1  TH        วัฒนา
# 18                                                NaN  TH       พระนคร
# 19                                                NaN  TH          NaN
# 20                                 Charoennakorn Road  TH       พระนคร
# 21                         266/9-10 Siam Square Soi 3  TH      ปทุมวัน
# 22                              Central Plaza RAMA IX  TH          NaN
# 23  12/500, 15 Sukhumvit Residences, Sukhumvit 15 ...  TH       พระนคร
# 24                                                NaN  TH          NaN
# 25                                     Gateway Ekamai  TH      คลองเตย
# 26                                  39/1 Lang Suan Rd  TH      ปทุมวัน
# 27                                   15 Rama 9 Soi 58  TH    Suanluang
# 28                                 37 Soi Saladaeng 2  TH       บางรัก
# 29                                                NaN  TH  Suriya Wong
# 30                                                NaN  TH          NaN
# 31                    Macau Government Tourist Office  TH       พระนคร
# 32                                   51 สุขุมวิทซอย11  TH       พระนคร
# 33                                     Kham pang phet  TH      Jatujak
# 34                                                NaN  TH     มักกะสัน
# 35                                                NaN  TH          NaN
# 36  56,58 Soi Pipat (Soi Sathorn 8), Sathorn Nuea ...  TH       บางรัก
# 37                                                NaN  TH          NaN
# 38                                     734 Rama 3 Rd.  TH      Yannawa
# 39                                       CentralWorld  TH      ปทุมวัน
# 40                                      Silom Complex  TH       บางรัก
# 41                            Esplanade Ratchadapisek  TH    Din Daeng
# 42                                                NaN  TH       พระนคร
# 43                                                NaN  TH          NaN
# 44                                                NaN  TH          NaN
# 45                                                NaN  TH          NaN
# 46                                                NaN  TH          NaN
# 47                                                NaN  TH   เขต ดินแดง
# 48                                        Siam Square  TH      ปทุมวัน
# 49                                                NaN  TH          NaN
#
#       country                     crossStreet  distance  \
# 0   ประเทศไทย     at Exchange Tower, 12th Fl.      3269
# 12  [Sukhumvit 35 or 33/1 (at sakura home 1st Fl.)...
# 13  [1 South Sathon Rd. (at Q.House Lumpini Life C...
# 14  [Charoennakorn Road, พระนคร, กรุงเทพมหานคร, ปร...
# 15  [2 Charoen Krung Road Soi 30, พระนคร, กรุงเทพม...
# 16  [Emporium (4th Fl, #4-8), คลองเตย, กรุงเทพมหาน...
# 17  [591/11-12 Soi Sukhumvit 33/1, วัฒนา, กรุงเทพม...
# 18                 [พระนคร, กรุงเทพมหานคร, ประเทศไทย]
# 19                                        [ประเทศไทย]
# 20  [Charoennakorn Road, พระนคร, กรุงเทพมหานคร, ปร...
# 21  [266/9-10 Siam Square Soi 3, ปทุมวัน, กรุงเทพม...
# 22       [Central Plaza RAMA IX (RAMA IX), ประเทศไทย]
# 23  [12/500, 15 Sukhumvit Residences, Sukhumvit 15...
# 24                                        [ประเทศไทย]
# 25  [Gateway Ekamai, คลองเตย, กรุงเทพมหานคร 10110,...
# 26  [39/1 Lang Suan Rd, ปทุมวัน, กรุงเทพมหานคร 103...
# 27  [15 Rama 9 Soi 58, Suanluang, กรุงเทพมหานคร 10...
# 28  [37 Soi Saladaeng 2 (Thanon Sala Daeng), บางรั...
# 29  [Soi Narathiwas 1, Suriya Wong, กรุงเทพมหานคร ...
# 30                                        [ประเทศไทย]
# 31  [Macau Government Tourist Office (Ploenchit), ...
# 32  [51 สุขุมวิทซอย11 (สุขุมวิท), พระนคร, กรุงเทพม...
# 33  [Kham pang phet, Jatujak, กรุงเทพมหานคร, ประเท...
# 34               [มักกะสัน, กรุงเทพมหานคร, ประเทศไทย]
# 35                                        [ประเทศไทย]
# 36  [56,58 Soi Pipat (Soi Sathorn 8), Sathorn Nuea...
# 37                                        [ประเทศไทย]
# 38  [734 Rama 3 Rd., Yannawa, กรุงเทพมหานคร 10120,...
# 39  [CentralWorld (6th Fl, Beacon Zone), ปทุมวัน, ...
# 40  [Silom Complex (B Fl.), บางรัก, กรุงเทพมหานคร ...
# 41  [Esplanade Ratchadapisek (2nd Fl), Din Daeng, ...
# 42           [พระนคร, กรุงเทพมหานคร 10330, ประเทศไทย]
# 43                                        [ประเทศไทย]
# 44                                        [ประเทศไทย]
# 45                                        [ประเทศไทย]
# 46                                        [ประเทศไทย]
# 47       [เขต ดินแดง, กรุงเทพมหานคร 10400, ประเทศไทย]
# 48  [Siam Square (near CU Book Center), ปทุมวัน, ก...
# 49                                        [ประเทศไทย]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lat': 13.73539709523547...  13.735397  100.561540
# 1   [{'label': 'display', 'lat': 13.7159605, 'lng'...  13.715960  100.571590
# 2   [{'label': 'display', 'lat': 13.757423, 'lng':...  13.757423  100.504490
# 3   [{'label': 'display', 'lat': 13.73320423739524...  13.733204  100.569351
# 4   [{'label': 'display', 'lat': 13.730388, 'lng':...  13.730388  100.582330
# 5   [{'label': 'display', 'lat': 13.74118385593264...  13.741184  100.551128
# 6   [{'label': 'display', 'lat': 13.72364013821049...  13.723640  100.556827
# 7   [{'label': 'display', 'lat': 13.743931, 'lng':...  13.743931  100.530260
# 8   [{'label': 'display', 'lat': 13.81175873634973...  13.811759  100.618591
# 9   [{'label': 'display', 'lat': 13.747911, 'lng':...  13.747911  100.490324
# 10  [{'label': 'display', 'lat': 13.74435423472377...  13.744354  100.542024
# 11  [{'label': 'display', 'lat': 13.714438, 'lng':...  13.714438  100.513426
# 12  [{'label': 'display', 'lat': 13.73311396487472...  13.733114  100.568958
# 13  [{'label': 'display', 'lat': 13.72588744101223...  13.725887  100.544535
# 14  [{'label': 'display', 'lat': 13.71588978021978...  13.715890  100.512935
# 15  [{'label': 'display', 'lat': 13.72875653956345...  13.728757  100.514092
# 16  [{'label': 'display', 'lat': 13.73008948758428...  13.730089  100.568558
# 17  [{'label': 'display', 'lat': 13.73244113159646...  13.732441  100.567996
# 18  [{'label': 'display', 'lat': 13.78157282692922...  13.781573  100.608887
# 19  [{'label': 'display', 'lat': 13.74296404624830...  13.742964  100.549188
# 20  [{'label': 'display', 'lat': 13.76058281512928...  13.760583  100.500769
# 21  [{'label': 'display', 'lat': 13.74526670262788...  13.745267  100.532944
# 22  [{'label': 'display', 'lat': 13.758271, 'lng':...  13.758271  100.566111
# 23  [{'label': 'display', 'lat': 13.74101609894506...  13.741016  100.558484
# 24  [{'label': 'display', 'lat': 13.741178, 'lng':...  13.741178  100.549662
# 25  [{'label': 'display', 'lat': 13.71856320549888...  13.718563  100.585348
# 26  [{'label': 'display', 'lat': 13.74166215906354...  13.741662  100.543542
# 27  [{'label': 'display', 'lat': 13.74084413968441...  13.740844  100.629122
# 28  [{'label': 'display', 'lat': 13.72764808987215...  13.727648  100.535314
# 29  [{'label': 'display', 'lat': 13.728481, 'lng':...  13.728481  100.529832
# 30  [{'label': 'display', 'lat': 13.74104, 'lng': ...  13.741040  100.548548
# 31  [{'label': 'display', 'lat': 13.742429, 'lng':...  13.742429  100.549050
# 32  [{'label': 'display', 'lat': 13.746908, 'lng':...  13.746908  100.557360
# 33  [{'label': 'display', 'lat': 13.799308, 'lng':...  13.799308  100.547090
# 34  [{'label': 'display', 'lat': 13.749186, 'lng':...  13.749186  100.561286
# 35  [{'label': 'display', 'lat': 13.740937, 'lng':...  13.740937  100.547736
# 36  [{'label': 'display', 'lat': 13.72260532007787...  13.722605  100.531554
# 37  [{'label': 'display', 'lat': 13.72757434844970...  13.727574  100.533409
# 38  [{'label': 'display', 'lat': 13.67753893851517...  13.677539  100.530004
# 39  [{'label': 'display', 'lat': 13.74665288311093...  13.746653  100.539946
# 40  [{'label': 'display', 'lat': 13.72841515660164...  13.728415  100.535108
# 41  [{'label': 'display', 'lat': 13.76570229011611...  13.765702  100.569595
# 42  [{'label': 'display', 'lat': 13.747235, 'lng':...  13.747235  100.534413
# 43  [{'label': 'display', 'lat': 13.74985817014671...  13.749858  100.540475
# 44  [{'label': 'display', 'lat': 13.74574201866964...  13.745742  100.530098
# 45  [{'label': 'display', 'lat': 13.759219, 'lng':...  13.759219  100.567875
# 46  [{'label': 'display', 'lat': 13.74919700622558...  13.749197  100.540565
# 47  [{'label': 'display', 'lat': 13.757669, 'lng':...  13.757669  100.554436
